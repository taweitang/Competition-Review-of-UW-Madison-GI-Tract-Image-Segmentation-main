# %% [markdown]
# Check the GPU resource

# %%
# !nvidia-smi

# %% [markdown]
# Environment

# %%
from google.colab import drive
drive.mount('/content/drive')
# !pip install -r /content/drive/MyDrive/3d_training_pipeline/requirements.txt
# !pip install -r /content/drive/MyDrive/3d_training_pipeline/requirements-dev.txt
# !pip install monai

# %% [markdown]
# Training Processing

# %%
# %cd /content/drive/MyDrive/3d_training_pipeline
# !python multilabel_train.py
